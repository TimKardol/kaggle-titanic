# %%
# import libraries
import pandas as pd

# Create dataframe from dataset
df = pd.read_csv("../datasets/test.csv")

# %% [markdown]
# ### Indicator 1.1: You describe data mining activities based on choice of a basic machine learning model  technique and relevant required activities

# %% [markdown]
# <font color='blue'>
# Read the description on https://www.kaggle.com/c/titanic
#
# * What is the goal of the competition?
# * What could be the "business goal" and success criteria behind it?
# * What is the context/ available information?
# * What is the information need?</font><font color='red'>
# * Which supervised machine learning technique should be applied?
# * What alternative machine learning models could be applied, and what would be the metric?
# * What will be your activities in each of the CRISP DM phases?
#
# </font>

# %% [markdown]
# ### Indicator 1.1 answers
# 1. The goal of the competition is to make a prediction about who had the most chance of surviving the sinking of the titanic.
# 2. What sort of people were more likely to survive the sinking?
# 3. Any information about the sinking of the titanic.
# 4. ?
# 5. Classification or regression.
# 6. ?
# 7. https://www.datascience-pm.com/crisp-dm-2/

# %% [markdown]
# ### Indicator 1.2: You define data mining goals success criteria

# %% [markdown]
# <font color='blue'>
# Read the evaluation on https://www.kaggle.com/c/titanic/overview/evaluation
#
# * What is the data mining goal and success criterion?
# * What is the metric, how does it relate to the criterion?
# * How will you interpret the metric?
# </font>

# %% [markdown]
# ### Indicator 1.2 answers
# 1. It is my job to predict if a passenger survived the sinking of the Titanic or not.
# 2. The metric is the accuracy of passengers that are correctly predicted to be dead.
# 3. ?

# %% [markdown]
# ### Indicator 1.3: You add extra self-organised and/or external data sources to the data science process

# %% [markdown]
# <font color='blue'>
# Describe this dataset:
#
# * What is the number of rows and number of columns?
# * Check the top and bottom rows of the dataset
# * What does each row in the data represent?
# * What is the data type of the columns, and what are the units?</font><font color='red'>
# * What is the measurement level of the columns?
# * What is the source of the data, how about confidentiality?
# * For this competition, what additional information (data sources) would be relevant?
# </font>

# %% [markdown]
# ### Indicator 1.3 answers
# 1. 418 rows and 11 columns.
# 2. A passenger on the titanic.

# %% [markdown]
# 3.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# 4. ?
# 5. Kaggle or archives.
# 6. Cabin locations, deck location to name a few.
